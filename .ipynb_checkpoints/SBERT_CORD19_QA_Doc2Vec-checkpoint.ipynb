# %% [markdown]
# <p align="center">
#  <img src="http://www.di.uoa.gr/themes/corporate_lite/logo_el.png" title="Department of Informatics and Telecommunications - University of Athens"/> </p>
#
# ---
# <h1 align="center">
#   Artificial Intelligence
# </h1>
# <h1 align="center" >
#   Deep Learning for Natural Language Processing
# </h1>
#
# ---
# <h2 align="center">
#  <b>Konstantinos Nikoletos</b>
# </h2>
#
# <h3 align="center">
#  <b>Winter 2020-2021</b>
# </h3>
#
#
# ---
# ---

# %% [markdown]
# ### __Task__
# This exercise is about developing a document retrieval system to return titles of scientific
# papers containing the answer to a given user question. You will use the first version of
# the COVID-19 Open Research Dataset (CORD-19) in your work (articles in the folder
# comm use subset).
#
#
# For example, for the question “What are the coronaviruses?”, your system can return the
# paper title “Distinct Roles for Sialoside and Protein Receptors in Coronavirus Infection”
# since this paper contains the answer to the asked question.
#
#
# To achieve the goal of this exercise, you will need first to read the paper Sentence-BERT:
# Sentence Embeddings using Siamese BERT-Networks, in order to understand how you
# can create sentence embeddings. In the related work of this paper, you will also find other
# approaches for developing your model. For example, you can using Glove embeddings,
# etc. In this link, you can find the extended versions of this dataset to test your model, if
# you want. You are required to:
#
#
# <ol type="a">
#   <li>Preprocess the provided dataset. You will decide which data of each paper is useful
# to your model in order to create the appropriate embeddings. You need to explain
# your decisions.</li>
#   <li>Implement at least 2 different sentence embedding approaches (see the related work
# of the Sentence-BERT paper), in order for your model to retrieve the titles of the
# papers related to a given question.</li>
#   <li>Compare your 2 models based on at least 2 different criteria of your choice. Explain
# why you selected these criteria, your implementation choices, and the results. Some
# questions you can pose are included here. You will need to provide the extra questions
# you posed to your model and the results of all the questions as well.</li>
# </ol>
#
# ### __Notebook__
#
#
# In this notebook I am going to create the Embeddings using Doc2Vec
#
#
# ---
# ---

# %% [markdown]
# __Import__ of essential libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import sys # only needed to determine Python version number
import matplotlib # only needed to determine Matplotlib version 
import nltk
from nltk.stem import WordNetLemmatizer
import pprint
import torch
import torch.nn as nn
import torch.optim as optim
from torchtext import data
import logging
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# Selecting device (GPU - CUDA if available)

# %%
# First checking if GPU is available
train_on_gpu=torch.cuda.is_available()

if(train_on_gpu):
    print('Training on GPU.')
else:
    print('No GPU available, training on CPU.')
# Out:
# Training on GPU.

# %% [markdown]
# # Loading data
# ---

# %%
# Opening data file
import io
from google.colab import drive
from os import listdir
from os.path import isfile, join
import json

drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Loading the dictionary if it has been created

# %%
#@title Select number of papers that will be feeded in the model { vertical-output: true, display-mode: "both" }
number_of_papers = "9000" #@param ["1000", "3000", "6000", "9000"]
import pickle

CORD19_Dataframe = r"/content/drive/My Drive/AI_4/CORD19_SentenceMap_"+number_of_papers+".pkl"
with open(CORD19_Dataframe, 'rb') as drivef:
  CORD19Dictionary = pickle.load(drivef)

# %% [markdown]
# OR the summary of the papers

# %%
#@title Select number of summarized papers that will be feeded in the model { vertical-output: true, display-mode: "both" }
number_of_papers = "9000" #@param ["1000", "3000", "6000", "9000"]
import pickle

CORD19_Dataframe = r"/content/drive/My Drive/AI_4/CORD19_SentenceMap_Summarized_"+number_of_papers+".pkl"
with open(CORD19_Dataframe, 'rb') as drivef:
  CORD19Dictionary = pickle.load(drivef)

# %% [markdown]
# ## Queries
# ---

# %%
query_list = [
  'What are the coronoviruses?',
  'What was discovered in Wuhuan in December 2019?',
  'What is Coronovirus Disease 2019?',
  'What is COVID-19?',
  'What is caused by SARS-COV2?', 'How is COVID-19 spread?',
  'Where was COVID-19 discovered?','How does coronavirus spread?'
]

proposed_answers = [
  'Coronaviruses (CoVs) are common human and animal pathogens that can transmit zoonotically and cause severe respiratory disease syndromes. ',
  'In December 2019, a novel coronavirus, called COVID-19, was discovered in Wuhan, China, and has spread to different cities in China as well as to 24 other countries.',
  'Coronavirus Disease 2019 (COVID-19) is an emerging disease with a rapid increase in cases and deaths since its first identification in Wuhan, China, in December 2019.',
  'COVID-19 is a viral respiratory illness caused by a new coronavirus called SARS-CoV-2.',
  'Coronavirus disease (COVID-19) is caused by SARS-COV2 and represents the causative agent of a potentially fatal disease that is of great global public health concern.', 
  'First, although COVID-19 is spread by the airborne route, air disinfection of cities and communities is not known to be effective for disease control and needs to be stopped.',
  'In December 2019, a novel coronavirus, called COVID-19, was discovered in Wuhan, China, and has spread to different cities in China as well as to 24 other countries.',
  'The new coronavirus was reported to spread via droplets, contact and natural aerosols from human-to-human.'
]

myquery_list = [
  "How long can the coronavirus survive on surfaces?",
  "What means COVID-19?",
  "Is COVID19 worse than flue?",
  "When the vaccine will be ready?",
  "Whats the proteins that consist COVID-19?",
  "Whats the symptoms of COVID-19?",
  "How can I prevent COVID-19?",
  "What treatments are available for COVID-19?",
  "Is hand sanitizer effective against COVID-19?",
  "Am I at risk for serious complications from COVID-19 if I smoke cigarettes?",
  "Are there any FDA-approved drugs (medicines) for COVID-19?",
  "How are people tested?",
  "Why is the disease being called coronavirus disease 2019, COVID-19?",
  "Am I at risk for COVID-19 from mail, packages, or products?",
  "What is community spread?",
  "How can I protect myself?",
  "What is a novel coronavirus?",
  "Was Harry Potter a good magician?"
]

# %% [markdown]
# # Results dataframes

# %%
resultsDf = pd.DataFrame(columns=['Number of papers','Embeddings creation time'])

queriesDf = pd.DataFrame(columns=['Query','Proposed_answer','Model_answer','Cosine_similarity'])
queriesDf['Query'] = query_list
queriesDf['Proposed_answer'] = proposed_answers

myQueriesDf = pd.DataFrame(columns=['Query','Model_answer','Cosine_similarity'])
myQueriesDf['Query'] = myquery_list

queriesDf
# Out:
#                                              Query  ... Cosine_similarity
# 0                      What are the coronoviruses?  ...               NaN
# 1  What was discovered in Wuhuan in December 2019?  ...               NaN
# 2                What is Coronovirus Disease 2019?  ...               NaN
# 3                                What is COVID-19?  ...               NaN
# 4                     What is caused by SARS-COV2?  ...               NaN
# 5                          How is COVID-19 spread?  ...               NaN
# 6                   Where was COVID-19 discovered?  ...               NaN
# 7                     How does coronavirus spread?  ...               NaN
#
# [8 rows x 4 columns]

# %% [markdown]
# # Doc2Vec
# ---

# %% [markdown]
# An extension of Word2Vec, the Doc2Vec embedding is one of the most popular techniques out there. Introduced in 2014, it is an unsupervised algorithm and adds on to the Word2Vec model by introducing another ‘paragraph vector’. Also, there are 2 ways to add the paragraph vector to the model.
#
# 1. PVDM(Distributed Memory version of Paragraph Vector): We assign a paragraph vector sentence while sharing word vectors among all sentences. Then we either average or concatenate the (paragraph vector and words vector) to get the final sentence representation. If you notice, it is an extension of the Continuous Bag-of-Word type of Word2Vec where we predict the next word given a set of words. It is just that in PVDM, we predict the next sentence given a set of sentences.
#
# <p align="center">
#  <img src="https://cdn.analyticsvidhya.com/wp-content/uploads/2020/08/PVDM.png" title="Department of Informatics and Telecommunications - University of Athens"/>
#  <p  align="center">Infersent Flow</p>
# </p>
#
# 2. PVDOBW( Distributed Bag of Words version of Paragraph Vector): Just lime PVDM, PVDOBW is another extension, this time of the Skip-gram type. Here, we just sample random words from the sentence and make the model predict which sentence it came from(a classification task).
#
# <p align="center">
#  <img src="https://cdn.analyticsvidhya.com/wp-content/uploads/2020/08/PVDOBW.png" title="Department of Informatics and Telecommunications - University of Athens"/>
#  <p  align="center">Infersent Flow</p>
# </p>
#
# The authors of the paper recommend using both in combination, but state that usually PVDM is more than enough for most tasks.

# %%
# from sentence_transformers import SentenceTransformer, util
import torch
import time
from nltk import word_tokenize
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %% [markdown]
# # Initializing corpus

# %%
# Encoding the papers
corpus = list(CORD19Dictionary.keys())

# %% [markdown]
# # Creating the embeddings
#
#
# ```
# vector_size = Dimensionality of the feature vectors.
# window = The maximum distance between the current and predicted word within a sentence.
# min_count = Ignores all words with total frequency lower than this.
# alpha = The initial learning rate.
# ```

# %%
tagged_data = [TaggedDocument(d, [i]) for i, d in enumerate(corpus)]

# %%
# %%time
model = Doc2Vec(tagged_data, vector_size = 20, window = 2, min_count = 1)
# Out:
# CPU times: user 2min 44s, sys: 21.9 s, total: 3min 5s
# Wall time: 2min 21s

# %% [markdown]
# # Evaluation
# ---

# %%
import re
from  nltk import tokenize
from termcolor import colored

def paperTitle(answer,SentenceMap):
  record = SentenceMap[answer]
  print("Paper title:",record[1])
  print("Paper id:   ",record[0])  

# Find the closest sentence of the corpus for each query sentence based on cosine similarity
def evaluation(topk,query_list,model,resultsDf):
  query_answers = []
  scores = []
  for query in query_list:

      test_doc = word_tokenize(query.lower())
      test_doc_vector = model.infer_vector(test_doc)


      most_similar = model.docvecs.most_similar(positive = [test_doc_vector])

      print("\n\n======================\n\n")
      print("Query:",colored(query,'green') )

      for k, (idx, score) in zip(range(0,topk),most_similar):
        print("\n-> ",k+1)
        answer = ' '.join([re.sub(r"^\[.*\]", "", x) for x in corpus[idx].split()])
        print("Score: {:.4f}".format(score))
        paperTitle(corpus[idx],CORD19Dictionary)
        print("Anser size: ",len(tokenize.word_tokenize(answer)))
        print("Anser: ")
        print(colored(answer,'yellow'))
        if(k == 0):
          scores.append(score)
          query_answers.append(answer)
  resultsDf['Model_answer'] = query_answers
  resultsDf['Cosine_similarity'] = scores

# %%
  top_k = 3
  evaluation(top_k,query_list,model,queriesDf)
# Out:
# ======================
#
#
# Query: What are the coronoviruses?
#
# ->  1
# Score: 0.7967
# Paper title: Bacillus subtilis and surfactin inhibit the transmissible gastroenteritis virus from entering the intestinal epithelial cells
# Paper id:    603e11d248463c9b79a1030663946c5640810536
# Anser size:  19
# Anser:
# Binding to the cellular receptor is the first step of CoV entry process [22, 23] .
#
# ->  2
# Score: 0.7912
# Paper title:
# Paper id:    b3574701bdaf6c4d408e9abe2d4176e058fc5208
# Anser size:  6
# Anser:
# 2009; Peel et al.
#
# ->  3
# Score: 0.7907
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
#
# ======================
#
#
# Query: What was discovered in Wuhuan in December 2019?
#
# ->  1
# Score: 0.8092
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
# ->  2
# Score: 0.7736
# Paper title: Gut Virome Analysis of Cameroonians Reveals High Diversity of Enteric Viruses, Including Potential Interspecies Transmitted Viruses
# Paper id:    311aaa859b69a54fba2d8a532fcf632599002edb
# Anser size:  1
# Anser:
# VIRSorter_NODE_25_length_14198_cov_12_3353-cat_2
#
# ->  3
# Score: 0.7596
# Paper title:
# Paper id:    b3574701bdaf6c4d408e9abe2d4176e058fc5208
# Anser size:  6
# Anser:
# 2009; Peel et al.
#
#
# ======================
#
#
# Query: What is Coronovirus Disease 2019?
#
# ->  1
# Score: 0.8379
# Paper title: Hemozoin-induced activation of human monocytes toward M2-like phenotype is partially reversed by antimalarial drugs- chloroquine and artemisinin
# Paper id:    232e85eda8060808405e79f0dbe13309eccddf58
# Anser size:  8
# Anser:
# The medium was replenished every 24 h.
#
# ->  2
# Score: 0.8104
# Paper title: Zika Virus Infection at Different Pregnancy Stages: Anatomopathological Findings, Target Cells and Viral Persistence in Placental Tissues
# Paper id:    b1d65769b15ff7bd395ae21186fd09642f69571f
# Anser size:  9
# Anser:
# RNA was stored at 80 C until use.
#
# ->  3
# Score: 0.8000
# Paper title: Bacillus subtilis and surfactin inhibit the transmissible gastroenteritis virus from entering the intestinal epithelial cells
# Paper id:    603e11d248463c9b79a1030663946c5640810536
# Anser size:  19
# Anser:
# Binding to the cellular receptor is the first step of CoV entry process [22, 23] .
#
#
# ======================
#
#
# Query: What is COVID-19?
#
# ->  1
# Score: 0.7731
# Paper title: Zika Virus Infection at Different Pregnancy Stages: Anatomopathological Findings, Target Cells and Viral Persistence in Placental Tissues
# Paper id:    b1d65769b15ff7bd395ae21186fd09642f69571f
# Anser size:  9
# Anser:
# RNA was stored at 80 C until use.
#
# ->  2
# Score: 0.7727
# Paper title: Bacillus subtilis and surfactin inhibit the transmissible gastroenteritis virus from entering the intestinal epithelial cells
# Paper id:    603e11d248463c9b79a1030663946c5640810536
# Anser size:  19
# Anser:
# Binding to the cellular receptor is the first step of CoV entry process [22, 23] .
#
# ->  3
# Score: 0.7605
# Paper title: Zoonotic parasites of dromedary camels: so important, so ignored
# Paper id:    6c4fd19f82c72d0d52f0de8c0290f522646c6da7
# Anser size:  12
# Anser:
# CE causes considerable medical costs and economic losses in endemic areas.
#
#
# ======================
#
#
# Query: What is caused by SARS-COV2?
#
# ->  1
# Score: 0.7959
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
# ->  2
# Score: 0.7832
# Paper title:
# Paper id:    b3574701bdaf6c4d408e9abe2d4176e058fc5208
# Anser size:  6
# Anser:
# 2009; Peel et al.
#
# ->  3
# Score: 0.7574
# Paper title: Emojis in public health and how they might be used for hand hygiene and infection prevention and control
# Paper id:    256425602cf068d42a6473d317890d0c0ac6a464
# Anser size:  10
# Anser:
# According to the study performed by Pan et al.
#
#
# ======================
#
#
# Query: How is COVID-19 spread?
#
# ->  1
# Score: 0.7893
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
# ->  2
# Score: 0.7738
# Paper title: Gut Virome Analysis of Cameroonians Reveals High Diversity of Enteric Viruses, Including Potential Interspecies Transmitted Viruses
# Paper id:    311aaa859b69a54fba2d8a532fcf632599002edb
# Anser size:  1
# Anser:
# VIRSorter_NODE_25_length_14198_cov_12_3353-cat_2
#
# ->  3
# Score: 0.7669
# Paper title:
# Paper id:    b3574701bdaf6c4d408e9abe2d4176e058fc5208
# Anser size:  6
# Anser:
# 2009; Peel et al.
#
#
# ======================
#
#
# Query: Where was COVID-19 discovered?
#
# ->  1
# Score: 0.8389
# Paper title: Gut Virome Analysis of Cameroonians Reveals High Diversity of Enteric Viruses, Including Potential Interspecies Transmitted Viruses
# Paper id:    311aaa859b69a54fba2d8a532fcf632599002edb
# Anser size:  1
# Anser:
# VIRSorter_NODE_25_length_14198_cov_12_3353-cat_2
#
# ->  2
# Score: 0.8222
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
# ->  3
# Score: 0.7832
# Paper title: Equine Rhinitis A Virus Infection in Thoroughbred Racehorses-A Putative Role in Poor Performance?
# Paper id:    1a383f04a8ddfeba2113f27e82c41d0582feb276
# Anser size:  9
# Anser:
# The statistical significance was set at = 0.05.
#
#
# ======================
#
#
# Query: How does coronavirus spread?
#
# ->  1
# Score: 0.8099
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
# ->  2
# Score: 0.7603
# Paper title: Nanoparticle-based vaccine development and evaluation against viral infections in pigs
# Paper id:    f6c3322832e870befdabba94767a6422dfd67d2b
# Anser size:  19
# Anser:
# PLGA NPs enhance antigen uptake and induce maturation of porcine APCs [62, 86, 87] .
#
# ->  3
# Score: 0.7536
# Paper title: Human Coronaviruses: A Review of Virus-Host Interactions
# Paper id:    30abdf7a423427b001aee5d319abecfb5ad1671b
# Anser size:  3
# Anser:
# 229E infection  .

# %%
  top_k = 3
  evaluation(top_k,myquery_list,model,myQueriesDf)
# Out:
# ======================
#
#
# Query: How long can the coronavirus survive on surfaces?
#
# ->  1
# Score: 0.8004
# Paper title:
# Paper id:    b3574701bdaf6c4d408e9abe2d4176e058fc5208
# Anser size:  6
# Anser:
# 2009; Peel et al.
#
# ->  2
# Score: 0.7923
# Paper title: Zoonotic parasites of dromedary camels: so important, so ignored
# Paper id:    6c4fd19f82c72d0d52f0de8c0290f522646c6da7
# Anser size:  12
# Anser:
# CE causes considerable medical costs and economic losses in endemic areas.
#
# ->  3
# Score: 0.7862
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
#
# ======================
#
#
# Query: What means COVID-19?
#
# ->  1
# Score: 0.7932
# Paper title: Contact chains of cattle farms in Great Britain
# Paper id:    e1d7e7883ad7d77a1c982c700f77e5ce09530fcf
# Anser size:  10
# Anser:
# -We have clarified in the methods at lines 180-191.
#
# ->  2
# Score: 0.7803
# Paper title: Potential Rapid Diagnostics, Vaccine and Therapeutics for 2019 Novel Coronavirus (2019-nCoV): A Systematic Review
# Paper id:    9b0c87f808b1b66f2937d7a7acb524a756b6113b
# Anser size:  10
# Anser:
# This decreases the effective R0 value of the disease.
#
# ->  3
# Score: 0.7685
# Paper title: Gut Virome Analysis of Cameroonians Reveals High Diversity of Enteric Viruses, Including Potential Interspecies Transmitted Viruses
# Paper id:    311aaa859b69a54fba2d8a532fcf632599002edb
# Anser size:  1
# Anser:
# VIRSorter_NODE_25_length_14198_cov_12_3353-cat_2
#
#
# ======================
#
#
# Query: Is COVID19 worse than flue?
#
# ->  1
# Score: 0.7990
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
# ->  2
# Score: 0.7582
# Paper title: Zika Virus Infection at Different Pregnancy Stages: Anatomopathological Findings, Target Cells and Viral Persistence in Placental Tissues
# Paper id:    b1d65769b15ff7bd395ae21186fd09642f69571f
# Anser size:  9
# Anser:
# RNA was stored at 80 C until use.
#
# ->  3
# Score: 0.7570
# Paper title: Nanoparticle-based vaccine development and evaluation against viral infections in pigs
# Paper id:    f6c3322832e870befdabba94767a6422dfd67d2b
# Anser size:  19
# Anser:
# PLGA NPs enhance antigen uptake and induce maturation of porcine APCs [62, 86, 87] .
#
#
# ======================
#
#
# Query: When the vaccine will be ready?
#
# ->  1
# Score: 0.8337
# Paper title: Hemozoin-induced activation of human monocytes toward M2-like phenotype is partially reversed by antimalarial drugs- chloroquine and artemisinin
# Paper id:    232e85eda8060808405e79f0dbe13309eccddf58
# Anser size:  8
# Anser:
# The medium was replenished every 24 h.
#
# ->  2
# Score: 0.7651
# Paper title: Bacillus subtilis and surfactin inhibit the transmissible gastroenteritis virus from entering the intestinal epithelial cells
# Paper id:    603e11d248463c9b79a1030663946c5640810536
# Anser size:  19
# Anser:
# Binding to the cellular receptor is the first step of CoV entry process [22, 23] .
#
# ->  3
# Score: 0.7570
# Paper title:
# Paper id:    b3574701bdaf6c4d408e9abe2d4176e058fc5208
# Anser size:  6
# Anser:
# 2009; Peel et al.
#
#
# ======================
#
#
# Query: Whats the proteins that consist COVID-19?
#
# ->  1
# Score: 0.7793
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
# ->  2
# Score: 0.7563
# Paper title: Gut Virome Analysis of Cameroonians Reveals High Diversity of Enteric Viruses, Including Potential Interspecies Transmitted Viruses
# Paper id:    311aaa859b69a54fba2d8a532fcf632599002edb
# Anser size:  1
# Anser:
# VIRSorter_NODE_2982_length_1113_cov_2_02703-cat_2
#
# ->  3
# Score: 0.7517
# Paper title: Gut Virome Analysis of Cameroonians Reveals High Diversity of Enteric Viruses, Including Potential Interspecies Transmitted Viruses
# Paper id:    311aaa859b69a54fba2d8a532fcf632599002edb
# Anser size:  1
# Anser:
# VIRSorter_NODE_25_length_14198_cov_12_3353-cat_2
#
#
# ======================
#
#
# Query: Whats the symptoms of COVID-19?
#
# ->  1
# Score: 0.8095
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
# ->  2
# Score: 0.7589
# Paper title: Gut Virome Analysis of Cameroonians Reveals High Diversity of Enteric Viruses, Including Potential Interspecies Transmitted Viruses
# Paper id:    311aaa859b69a54fba2d8a532fcf632599002edb
# Anser size:  1
# Anser:
# VIRSorter_NODE_25_length_14198_cov_12_3353-cat_2
#
# ->  3
# Score: 0.7542
# Paper title: Evolutionary and Phylogenetic Analysis of the Hepaciviruses and Pegiviruses
# Paper id:    4d10ef49bd91ac16d18f53f428f4ef3acc96469a
# Anser size:  6
# Anser:
# 2012; Lyons et al.
#
#
# ======================
#
#
# Query: How can I prevent COVID-19?
#
# ->  1
# Score: 0.8110
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
# ->  2
# Score: 0.7924
# Paper title: Gut Virome Analysis of Cameroonians Reveals High Diversity of Enteric Viruses, Including Potential Interspecies Transmitted Viruses
# Paper id:    311aaa859b69a54fba2d8a532fcf632599002edb
# Anser size:  1
# Anser:
# VIRSorter_NODE_25_length_14198_cov_12_3353-cat_2
#
# ->  3
# Score: 0.7721
# Paper title: Gut Virome Analysis of Cameroonians Reveals High Diversity of Enteric Viruses, Including Potential Interspecies Transmitted Viruses
# Paper id:    311aaa859b69a54fba2d8a532fcf632599002edb
# Anser size:  1
# Anser:
# VIRSorter_NODE_2982_length_1113_cov_2_02703-cat_2
#
#
# ======================
#
#
# Query: What treatments are available for COVID-19?
#
# ->  1
# Score: 0.7614
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
# ->  2
# Score: 0.7602
# Paper title: Zoonotic parasites of dromedary camels: so important, so ignored
# Paper id:    6c4fd19f82c72d0d52f0de8c0290f522646c6da7
# Anser size:  12
# Anser:
# CE causes considerable medical costs and economic losses in endemic areas.
#
# ->  3
# Score: 0.7545
# Paper title: A Multi-Omics Study of Chicken Infected by Nephropathogenic Infectious Bronchitis Virus
# Paper id:    0f93e8fef9ce127337fa00f8b16607d39c6415e8
# Anser size:  10
# Anser:
# The energy was -70 eV in electron impact mode.
#
#
# ======================
#
#
# Query: Is hand sanitizer effective against COVID-19?
#
# ->  1
# Score: 0.8105
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
# ->  2
# Score: 0.7724
# Paper title: Bacillus subtilis and surfactin inhibit the transmissible gastroenteritis virus from entering the intestinal epithelial cells
# Paper id:    603e11d248463c9b79a1030663946c5640810536
# Anser size:  19
# Anser:
# Binding to the cellular receptor is the first step of CoV entry process [22, 23] .
#
# ->  3
# Score: 0.7585
# Paper title: Zoonotic parasites of dromedary camels: so important, so ignored
# Paper id:    6c4fd19f82c72d0d52f0de8c0290f522646c6da7
# Anser size:  12
# Anser:
# CE causes considerable medical costs and economic losses in endemic areas.
#
#
# ======================
#
#
# Query: Am I at risk for serious complications from COVID-19 if I smoke cigarettes?
#
# ->  1
# Score: 0.8240
# Paper title:
# Paper id:    b3574701bdaf6c4d408e9abe2d4176e058fc5208
# Anser size:  6
# Anser:
# 2009; Peel et al.
#
# ->  2
# Score: 0.7913
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
# ->  3
# Score: 0.7756
# Paper title: Bacillus subtilis and surfactin inhibit the transmissible gastroenteritis virus from entering the intestinal epithelial cells
# Paper id:    603e11d248463c9b79a1030663946c5640810536
# Anser size:  19
# Anser:
# Binding to the cellular receptor is the first step of CoV entry process [22, 23] .
#
#
# ======================
#
#
# Query: Are there any FDA-approved drugs (medicines) for COVID-19?
#
# ->  1
# Score: 0.8110
# Paper title: Cryo-EM Studies of Virus-Antibody Immune Complexes
# Paper id:    9dc436e46261781fe2991baeff4ddc7dd2e96c9b
# Anser size:  6
# Anser:
# 2014; Rao et al.
#
# ->  2
# Score: 0.8053
# Paper title: Dam characteristics associated with pre-weaning diarrhea in mink (Neovison vison)
# Paper id:    88fb5713a61697d45f7d08a3b36012f955d354c9
# Anser size:  24
# Anser:
# Out of 70 dams included in the study 45 (64.3%) were young (1-year) and 25 dams were older.
#
# ->  3
# Score: 0.8009
# Paper title: Benefits and Inputs From Lactic Acid Bacteria and Their Bacteriocins as Alternatives to Antibiotic Growth Promoters During Food-Animal Production
# Paper id:    da2087c111ef9c8894c1dd1644d66a3aca35de9e
# Anser size:  17
# Anser:
# LAB are producing lactic acid as the main product of sugar metabolism (Russo et al.,
#
#
# ======================
#
#
# Query: How are people tested?
#
# ->  1
# Score: 0.7733
# Paper title:
# Paper id:    b3574701bdaf6c4d408e9abe2d4176e058fc5208
# Anser size:  6
# Anser:
# 2009; Peel et al.
#
# ->  2
# Score: 0.7575
# Paper title: Zika Virus Infection at Different Pregnancy Stages: Anatomopathological Findings, Target Cells and Viral Persistence in Placental Tissues
# Paper id:    b1d65769b15ff7bd395ae21186fd09642f69571f
# Anser size:  9
# Anser:
# RNA was stored at 80 C until use.
#
# ->  3
# Score: 0.7568
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
#
# ======================
#
#
# Query: Why is the disease being called coronavirus disease 2019, COVID-19?
#
# ->  1
# Score: 0.7754
# Paper title:
# Paper id:    b3574701bdaf6c4d408e9abe2d4176e058fc5208
# Anser size:  6
# Anser:
# 2009; Peel et al.
#
# ->  2
# Score: 0.7489
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
# ->  3
# Score: 0.7477
# Paper title: Seroconversion to HCoV-NL63 in Rhesus Macaques
# Paper id:    ec4a332b863ec8c1bbf94d605b17c67acddf0889
# Anser size:  11
# Anser:
# The generation of the plasmid construct was performed as described  .
#
#
# ======================
#
#
# Query: Am I at risk for COVID-19 from mail, packages, or products?
#
# ->  1
# Score: 0.7665
# Paper title: The Effect of Vaccination on the Evolution and Population Dynamics of Avian Paramyxovirus-1
# Paper id:    5ca920dabf09c2c2dd2c62f8ef5917e3bd72f087
# Anser size:  12
# Anser:
# Viruses belonging to genotypes I-IV have circulated since the 1930's.
#
# ->  2
# Score: 0.7604
# Paper title: metabolites H OH OH The metaRbolomics Toolbox in Bioconductor and beyond
# Paper id:    8c44e37bccf0c2a493e1b1754081384fc802d3d9
# Anser size:  3
# Anser:
# Package Reference Repos
#
# ->  3
# Score: 0.7585
# Paper title:
# Paper id:    b3574701bdaf6c4d408e9abe2d4176e058fc5208
# Anser size:  6
# Anser:
# 2009; Peel et al.
#
#
# ======================
#
#
# Query: What is community spread?
#
# ->  1
# Score: 0.8201
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
# ->  2
# Score: 0.7871
# Paper title: Gut Virome Analysis of Cameroonians Reveals High Diversity of Enteric Viruses, Including Potential Interspecies Transmitted Viruses
# Paper id:    311aaa859b69a54fba2d8a532fcf632599002edb
# Anser size:  1
# Anser:
# VIRSorter_NODE_2982_length_1113_cov_2_02703-cat_2
#
# ->  3
# Score: 0.7764
# Paper title: Gut Virome Analysis of Cameroonians Reveals High Diversity of Enteric Viruses, Including Potential Interspecies Transmitted Viruses
# Paper id:    311aaa859b69a54fba2d8a532fcf632599002edb
# Anser size:  1
# Anser:
# VIRSorter_NODE_25_length_14198_cov_12_3353-cat_2
#
#
# ======================
#
#
# Query: How can I protect myself?
#
# ->  1
# Score: 0.8005
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.
#
# ->  2
# Score: 0.7959
# Paper title: Bacillus subtilis and surfactin inhibit the transmissible gastroenteritis virus from entering the intestinal epithelial cells
# Paper id:    603e11d248463c9b79a1030663946c5640810536
# Anser size:  19
# Anser:
# Binding to the cellular receptor is the first step of CoV entry process [22, 23] .
#
# ->  3
# Score: 0.7845
# Paper title:
# Paper id:    b3574701bdaf6c4d408e9abe2d4176e058fc5208
# Anser size:  6
# Anser:
# 2009; Peel et al.
#
#
# ======================
#
#
# Query: What is a novel coronavirus?
#
# ->  1
# Score: 0.7580
# Paper title: Hemozoin-induced activation of human monocytes toward M2-like phenotype is partially reversed by antimalarial drugs- chloroquine and artemisinin
# Paper id:    232e85eda8060808405e79f0dbe13309eccddf58
# Anser size:  8
# Anser:
# The medium was replenished every 24 h.
#
# ->  2
# Score: 0.7466
# Paper title: Dogs (Canis familiaris) as Sentinels for Human Infectious Disease and Application to Canadian Populations: A Systematic Review
# Paper id:    a95452bb03845776e74c5af3dd628cb5c25a02aa
# Anser size:  10
# Anser:
# The final search was conducted on 1 December 2017.
#
# ->  3
# Score: 0.7243
# Paper title: Potential Rapid Diagnostics, Vaccine and Therapeutics for 2019 Novel Coronavirus (2019-nCoV): A Systematic Review
# Paper id:    9b0c87f808b1b66f2937d7a7acb524a756b6113b
# Anser size:  10
# Anser:
# This decreases the effective R0 value of the disease.
#
#
# ======================
#
#
# Query: Was Harry Potter a good magician?
#
# ->  1
# Score: 0.8165
# Paper title:
# Paper id:    b3574701bdaf6c4d408e9abe2d4176e058fc5208
# Anser size:  6
# Anser:
# 2009; Peel et al.
#
# ->  2
# Score: 0.8046
# Paper title: Potential Rapid Diagnostics, Vaccine and Therapeutics for 2019 Novel Coronavirus (2019-nCoV): A Systematic Review
# Paper id:    9b0c87f808b1b66f2937d7a7acb524a756b6113b
# Anser size:  10
# Anser:
# This decreases the effective R0 value of the disease.
#
# ->  3
# Score: 0.7780
# Paper title: Climate Change Could Increase the Geographic Extent of Hendra Virus Spillover Risk
# Paper id:    62df738127972a011de37d5c27776c48442889a9
# Anser size:  6
# Anser:
# 2008; Wiens et al.

# %% [markdown]
# # Overall results

# %% [markdown]
# ## 9000 papers with no summarization
# ---
#
# ### Time needed for creating the embeddings:
# - CPU times:
#   - user 25min 13s
#   - sys: 2min 35s
#   - total: 27min 48s
# - Wall time: 19min 20s
#
# ### Remarks
# Terrible results, I believe that I am doing something wrong in the way I use these embeddings. No remarks need to be checked again but didn't have the time.

# %% [markdown]
# ### Results

# %%
with pd.option_context('display.max_colwidth', None):
  display(queriesDf)
# Out:
#                                              Query  ... Cosine_similarity
# 0                      What are the coronoviruses?  ...          0.879537
# 1  What was discovered in Wuhuan in December 2019?  ...          0.806609
# 2                What is Coronovirus Disease 2019?  ...          0.834787
# 3                                What is COVID-19?  ...          0.748369
# 4                     What is caused by SARS-COV2?  ...          0.830321
# 5                          How is COVID-19 spread?  ...          0.833483
# 6                   Where was COVID-19 discovered?  ...          0.825443
# 7                     How does coronavirus spread?  ...          0.755793
#
# [8 rows x 4 columns]

# %%
with pd.option_context('display.max_colwidth', None):
  display(myQueriesDf)
# Out:
#                                                                           Query  ...                                                                                                                                                                                                                                                                                                                               Model_answer
# 0                             How long can the coronavirus survive on surfaces?  ...                                                                                                                                                                                                                                                                     Nineteen 2-ml fractions were collected from the bottom of the cushion.
# 1                                                          What means COVID-19?  ...                                                                                                                                                                                                                                                   Pathway classification according to canonical pathways was performed using IPA software.
# 2                                                   Is COVID19 worse than flue?  ...  During ascent, an off set appeared for all respiratory parameters: Vt increased by 59% and PmEI by 53% between 0 and 8,000 ft. During descent, the off set was reversely directed with a 39% decrease in Vt and a 28% decrease in PmEE between 8,000 and 0 ft. Modifying working pressure adequately corrected PmEI and PmEE, but not Vt.
# 3                                               When the vaccine will be ready?  ...                                                                                                                                                                                                                                                   Pathway classification according to canonical pathways was performed using IPA software.
# 4                                     Whats the proteins that consist COVID-19?  ...                                                                                                                                                                                                                                                                     Nineteen 2-ml fractions were collected from the bottom of the cushion.
# 5                                               Whats the symptoms of COVID-19?  ...  During ascent, an off set appeared for all respiratory parameters: Vt increased by 59% and PmEI by 53% between 0 and 8,000 ft. During descent, the off set was reversely directed with a 39% decrease in Vt and a 28% decrease in PmEE between 8,000 and 0 ft. Modifying working pressure adequately corrected PmEI and PmEE, but not Vt.
# 6                                                   How can I prevent COVID-19?  ...                                                                                                                                                                                                                                                               Two Zn 2+ binding sites have been identified in NS5 RdRP crystal structures.
# 7                                   What treatments are available for COVID-19?  ...                                                                                                                                                                                                                                                   Pathway classification according to canonical pathways was performed using IPA software.
# 8                                 Is hand sanitizer effective against COVID-19?  ...                                                                                                                                                                                                                                                   Pathway classification according to canonical pathways was performed using IPA software.
# 9   Am I at risk for serious complications from COVID-19 if I smoke cigarettes?  ...                                                                                                                                                                                                                                                   Pathway classification according to canonical pathways was performed using IPA software.
# 10                   Are there any FDA-approved drugs (medicines) for COVID-19?  ...                                                                                                                                   Briefly, the retroviral vector plasmid pMXs-puro GFP (Addgene) and packaging plasmids (pCMV-gag-pol-PA and pCMV-VSVg) were introduced into HEK293T cells using GeneJuice transfection reagent (Novagen).
# 11                                                       How are people tested?  ...  During ascent, an off set appeared for all respiratory parameters: Vt increased by 59% and PmEI by 53% between 0 and 8,000 ft. During descent, the off set was reversely directed with a 39% decrease in Vt and a 28% decrease in PmEE between 8,000 and 0 ft. Modifying working pressure adequately corrected PmEI and PmEE, but not Vt.
# 12          Why is the disease being called coronavirus disease 2019, COVID-19?  ...  During ascent, an off set appeared for all respiratory parameters: Vt increased by 59% and PmEI by 53% between 0 and 8,000 ft. During descent, the off set was reversely directed with a 39% decrease in Vt and a 28% decrease in PmEE between 8,000 and 0 ft. Modifying working pressure adequately corrected PmEI and PmEE, but not Vt.
# 13                  Am I at risk for COVID-19 from mail, packages, or products?  ...  During ascent, an off set appeared for all respiratory parameters: Vt increased by 59% and PmEI by 53% between 0 and 8,000 ft. During descent, the off set was reversely directed with a 39% decrease in Vt and a 28% decrease in PmEE between 8,000 and 0 ft. Modifying working pressure adequately corrected PmEI and PmEE, but not Vt.
# 14                                                    What is community spread?  ...                                                                                                                                                                                                                                                   Pathway classification according to canonical pathways was performed using IPA software.
# 15                                                    How can I protect myself?  ...  During ascent, an off set appeared for all respiratory parameters: Vt increased by 59% and PmEI by 53% between 0 and 8,000 ft. During descent, the off set was reversely directed with a 39% decrease in Vt and a 28% decrease in PmEE between 8,000 and 0 ft. Modifying working pressure adequately corrected PmEI and PmEE, but not Vt.
# 16                                                 What is a novel coronavirus?  ...                                                                                                                                                                                                                                         4 h later with 10 3 PFU of ZIKV strain SZ01, instead of 10 5 PFU as used in the therapeutic study.
# 17                                            Was Harry Potter a good magician?  ...                                                                                                                                                                                                                                                   Pathway classification according to canonical pathways was performed using IPA software.
#
# [18 rows x 4 columns]

# %% [markdown]
# ## 9000 papers and summarization
# ---
#
# ### Time needed for creating the embeddings:
# - CPU times:
#   - user 17min 51s
#   - sys: 11min 38s
#   - total: 29min 29s
# - Wall time: 29min 11s
#
# ### Remarks
#
# Same as above.

# %% [markdown]
# ### Results

# %%
with pd.option_context('display.max_colwidth', None):
  display(queriesDf)
# Out:
#                                              Query  ... Cosine_similarity
# 0                      What are the coronoviruses?  ...          0.796678
# 1  What was discovered in Wuhuan in December 2019?  ...          0.809173
# 2                What is Coronovirus Disease 2019?  ...          0.837877
# 3                                What is COVID-19?  ...          0.773054
# 4                     What is caused by SARS-COV2?  ...          0.795900
# 5                          How is COVID-19 spread?  ...          0.789324
# 6                   Where was COVID-19 discovered?  ...          0.838882
# 7                     How does coronavirus spread?  ...          0.809900
#
# [8 rows x 4 columns]

# %%
with pd.option_context('display.max_colwidth', None):
  display(myQueriesDf)
# Out:
#                                                                           Query  ... Cosine_similarity
# 0                             How long can the coronavirus survive on surfaces?  ...          0.800417
# 1                                                          What means COVID-19?  ...          0.793196
# 2                                                   Is COVID19 worse than flue?  ...          0.799016
# 3                                               When the vaccine will be ready?  ...          0.833728
# 4                                     Whats the proteins that consist COVID-19?  ...          0.779292
# 5                                               Whats the symptoms of COVID-19?  ...          0.809461
# 6                                                   How can I prevent COVID-19?  ...          0.811007
# 7                                   What treatments are available for COVID-19?  ...          0.761357
# 8                                 Is hand sanitizer effective against COVID-19?  ...          0.810513
# 9   Am I at risk for serious complications from COVID-19 if I smoke cigarettes?  ...          0.824034
# 10                   Are there any FDA-approved drugs (medicines) for COVID-19?  ...          0.810964
# 11                                                       How are people tested?  ...          0.773285
# 12          Why is the disease being called coronavirus disease 2019, COVID-19?  ...          0.775441
# 13                  Am I at risk for COVID-19 from mail, packages, or products?  ...          0.766456
# 14                                                    What is community spread?  ...          0.820052
# 15                                                    How can I protect myself?  ...          0.800472
# 16                                                 What is a novel coronavirus?  ...          0.757963
# 17                                            Was Harry Potter a good magician?  ...          0.816481
#
# [18 rows x 3 columns]

# %% [markdown]
# # References
#
# [1] https://colab.research.google.com/drive/1l6stpYdRMmeDBK_vw0L5NitdiAuhdsAr?usp=sharing#scrollTo=D_hDi8KzNgMM
#
# [2] https://www.sbert.net/docs/package_reference/cross_encoder.html
#
# [3]
